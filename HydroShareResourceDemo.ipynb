# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data_dir = '../downloads/757ed05854ab430dae99841f44622283/757ed05854ab430dae99841f44622283/data/contents/'

# %%
WY = 2010 #np.arange(2008,2019) # water year (integer)

file_name = 'WY_'+str(WY)+'_UpMetS_soil_snow_daily.csv' # file name (string)
file_name
# Out:
# 'WY_2010_UpMetS_soil_snow_daily.csv'

# %%
df = pd.read_csv(data_dir+file_name)
df
# Out:
#       date_time   Year   Month   Day   DOY   Decimal_year   W_Year   WYD  \
# 0    10/01/2009   2009      10     1   274       0.749315     2010     1
# 1    10/02/2009   2009      10     2   275       0.752055     2010     2
# 2    10/03/2009   2009      10     3   276       0.754795     2010     3
# 3    10/04/2009   2009      10     4   277       0.757534     2010     4
# 4    10/05/2009   2009      10     5   278       0.760274     2010     5
# ..          ...    ...     ...   ...   ...            ...      ...   ...
# 360  09/26/2010   2010       9    26   269       0.735616     2010   361
# 361  09/27/2010   2010       9    27   270       0.738356     2010   362
# 362  09/28/2010   2010       9    28   271       0.741096     2010   363
# 363  09/29/2010   2010       9    29   272       0.743836     2010   364
# 364  09/30/2010   2010       9    30   273       0.746575     2010   365
#
#       Decimal_WYear   VWC Qkde10   ...    Min.31   Air_temp_Acde  deg C  \
# ...

# %%
# Print all column names
for col in df.columns:
    print(col)
# Out:
# date_time
#  Year
#  Month
#  Day
#  DOY
#  Decimal_year
#  W_Year
#  WYD
#  Decimal_WYear
#  VWC Qkde10
#  Max
#   Min
#  VWC Qkuc10
#  Max.1
#   Min.1
#  VWC Acde10
#  Max.2
#   Min.2
#  VWC Acuc10
#  Max.3
#   Min.3
#  VWC Qkde30
#  Max.4
#   Min.4
#  VWC Qkuc30
#  Max.5
#   Min.5
#  VWC Open30
#  Max.6
#   Min.6
#  VWC Acde30
#  Max.7
#   Min.7
#  VWC Acuc30
#  Max.8
#   Min.8
#  VWC Qkde60
#  Max.9
#   Min.9
#  VWC Qkuc60
#  Max.10
#   Min.10
#  VWC Open60
#  Max.11
#   Min.11
#  VWC Acde60
#  Max.12
#   Min.12
#  VWC Acuc60
#  Max.13
#   Min.13
#  VWC Qkuc90
#  Max.14
#   Min.14
#  Temp Qkde10 deg C
#   Max
#   Min.15
#  Temp Qkuc10 deg C
#   Max.1
#   Min.16
#  Temp Acde10 deg C
#   Max.2
#   Min.17
#  Temp Acuc10 deg C
#   Max.3
#   Min.18
#  Temp Qkde30 deg C
#   Max.4
#   Min.19
#  Temp Qkuc30 deg C
#   Max.5
#   Min.20
#  Temp Open30 deg C
#   Max.6
#   Min.21
#  Temp Acde30 deg C
#   Max.7
#   Min.22
#  Temp Acuc30 deg C
#   Max.8
#   Min.23
#  Temp Qkde60 deg C
# ...

# %%
list(df.columns.values)
#df[' depth_Qkde cm '].plot
# Out:
# ['date_time',
#  ' Year',
#  ' Month',
#  ' Day',
#  ' DOY',
#  ' Decimal_year',
#  ' W_Year',
#  ' WYD',
#  ' Decimal_WYear',
#  ' VWC Qkde10 ',
#  ' Max',
#  '  Min',
#  ' VWC Qkuc10 ',
#  ' Max.1',
#  '  Min.1',
#  ' VWC Acde10 ',
#  ' Max.2',
#  '  Min.2',
#  ' VWC Acuc10 ',
#  ' Max.3',
#  '  Min.3',
#  ' VWC Qkde30 ',
#  ' Max.4',
#  '  Min.4',
#  ' VWC Qkuc30 ',
#  ' Max.5',
#  '  Min.5',
#  ' VWC Open30 ',
#  ' Max.6',
#  '  Min.6',
#  ' VWC Acde30 ',
#  ' Max.7',
#  '  Min.7',
#  ' VWC Acuc30 ',
#  ' Max.8',
#  '  Min.8',
#  ' VWC Qkde60 ',
#  ' Max.9',
#  '  Min.9',
#  ' VWC Qkuc60 ',
#  ' Max.10',
#  '  Min.10',
#  ' VWC Open60 ',
#  ' Max.11',
#  '  Min.11',
#  ' VWC Acde60 ',
#  ' Max.12',
#  '  Min.12',
#  ' VWC Acuc60 ',
#  ' Max.13',
#  '  Min.13',
#  ' VWC Qkuc90 ',
#  ' Max.14',
#  '  Min.14',
#  ' Temp Qkde10 deg C',
#  '  Max',
#  '  Min.15',
#  ' Temp Qkuc10 deg C',
#  '  Max.1',
#  '  Min.16',
#  ' Temp Acde10 deg C',
#  '  Max.2',
#  '  Min.17',
# ...

# %%
df.plot(x='date_time',y=' depth_Qkuc cm')
# Out:
# <AxesSubplot:xlabel='date_time'>
